# %%
import numpy
print(numpy.__version__)
# Out:
# 1.19.5

# %%
from platform import python_version
print("Current Python Version-", python_version())
# Out:
# Current Python Version- 3.6.5

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.13.1

# %%
import h5py

print("HDF5 Version:", h5py.__version__)
# Out:
# HDF5 Version: 2.7.1

# %%
import keras
print(keras.__version__)
# Out:
# 2.2.4
# Using TensorFlow backend.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os

NUM_EPOCHS = 150
STEPS_PER_EPOCH_TRAINING = 4
STEPS_PER_EPOCH_VALIDATION = 2
BATCH_SIZE_TRAINING = 32
BATCH_SIZE_VALIDATION = 8
BATCH_SIZE_TESTING = 1

import keras
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.models import Sequential
from keras import optimizers
from keras import regularizers
from keras.layers.normalization import BatchNormalization

def cnn(input_shape=(29,29,3)):
  
	model = Sequential()
	model.add(Conv2D(64, kernel_size=(4, 4), activation='relu', input_shape=input_shape))
	model.add(BatchNormalization())
	model.add(MaxPooling2D(pool_size=(2, 4)))

	
    
	model.add(Conv2D(64, (3, 5), activation='relu', kernel_regularizer=regularizers.l2(0.04)))
	model.add(MaxPooling2D(pool_size=(2, 1)))

	model.add(Dropout(0.2))
    
	model.add(Conv2D(64, (2, 2), activation='relu', padding='same'))

	model.add(BatchNormalization())
	model.add(MaxPooling2D(pool_size=(2, 2)))
	model.add(Dropout(0.2))
    
	model.add(Flatten())
    
	model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.04)))
	model.add(Dropout(0.5))
	model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.04)))
    
	model.add(Dense(3, activation='softmax'))
  
	model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0),
                  metrics=['accuracy'])
 
	model.summary()
	return model

model = cnn()

from keras.applications.vgg16 import preprocess_input
from keras.preprocessing.image import ImageDataGenerator

data_generator = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = data_generator.flow_from_directory(
        'dataset/train',
        target_size=(29, 29),
        batch_size=BATCH_SIZE_TRAINING,
        class_mode='categorical')

validation_generator = data_generator.flow_from_directory(
        'dataset/test',
        target_size=(29, 29),
        batch_size=BATCH_SIZE_VALIDATION,
        class_mode='categorical')



fit_history = model.fit_generator(
        train_generator,
        steps_per_epoch=STEPS_PER_EPOCH_TRAINING,
        epochs = NUM_EPOCHS,
        validation_data=validation_generator,
        validation_steps=STEPS_PER_EPOCH_VALIDATION
)

model.save('model_cnn_dyslexia.h5')

#print(fit_history.history.keys())

plt.figure(1, figsize = (15,8)) 
    
plt.subplot(221)  
plt.plot(fit_history.history['acc'])  
plt.plot(fit_history.history['val_acc'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 
    
plt.subplot(222)  
plt.plot(fit_history.history['loss'])  
plt.plot(fit_history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 
plt.savefig("accuracy.png")
plt.show()
plt.close()
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 64)        3136
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 26, 26, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 6, 64)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 2, 64)         61504
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 2, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 2, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 2, 64)          16448
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5, 2, 64)          256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 1, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 1, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 92,035
# Trainable params: 91,779
# Non-trainable params: 256
# _________________________________________________________________
# Found 151649 images belonging to 3 classes.
# Found 56723 images belonging to 3 classes.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/150
# 4/4 [==============================] - 5s 1s/step - loss: 9.3462 - acc: 0.3438 - val_loss: 8.5384 - val_acc: 0.4375
# Epoch 2/150
# 4/4 [==============================] - 1s 335ms/step - loss: 8.8787 - acc: 0.4766 - val_loss: 8.7066 - val_acc: 0.4375
# Epoch 3/150
# 4/4 [==============================] - 1s 325ms/step - loss: 8.7670 - acc: 0.4141 - val_loss: 8.5229 - val_acc: 0.3750
# Epoch 4/150
# 4/4 [==============================] - 1s 326ms/step - loss: 8.4242 - acc: 0.3906 - val_loss: 7.8078 - val_acc: 0.6875
# Epoch 5/150
# 4/4 [==============================] - 1s 361ms/step - loss: 8.3146 - acc: 0.4453 - val_loss: 7.6873 - val_acc: 0.7500
# Epoch 6/150
# 4/4 [==============================] - 1s 331ms/step - loss: 7.8998 - acc: 0.5234 - val_loss: 7.6345 - val_acc: 0.6250
# Epoch 7/150
# 4/4 [==============================] - 1s 331ms/step - loss: 7.7896 - acc: 0.4531 - val_loss: 7.4477 - val_acc: 0.6250
# Epoch 8/150
# 4/4 [==============================] - 1s 322ms/step - loss: 7.6659 - acc: 0.5469 - val_loss: 7.3682 - val_acc: 0.5000
# Epoch 9/150
# 4/4 [==============================] - 1s 319ms/step - loss: 7.4838 - acc: 0.4922 - val_loss: 7.0617 - val_acc: 0.6875
# Epoch 10/150
# 4/4 [==============================] - 1s 306ms/step - loss: 7.1923 - acc: 0.6406 - val_loss: 7.0322 - val_acc: 0.5000
# Epoch 11/150
# 4/4 [==============================] - 1s 307ms/step - loss: 7.0345 - acc: 0.6016 - val_loss: 7.0162 - val_acc: 0.5000
# Epoch 12/150
# 4/4 [==============================] - 1s 325ms/step - loss: 6.9384 - acc: 0.5547 - val_loss: 6.6837 - val_acc: 0.5000
# Epoch 13/150
# 4/4 [==============================] - 1s 349ms/step - loss: 6.7525 - acc: 0.5703 - val_loss: 6.5860 - val_acc: 0.5625
# Epoch 14/150
# 4/4 [==============================] - 1s 333ms/step - loss: 6.5748 - acc: 0.5156 - val_loss: 6.3405 - val_acc: 0.7500
# Epoch 15/150
# 4/4 [==============================] - 1s 320ms/step - loss: 6.3379 - acc: 0.6328 - val_loss: 6.2312 - val_acc: 0.6250
# Epoch 16/150
# 4/4 [==============================] - 1s 311ms/step - loss: 6.2226 - acc: 0.6094 - val_loss: 6.1993 - val_acc: 0.6250
# Epoch 17/150
# 4/4 [==============================] - 1s 297ms/step - loss: 6.0410 - acc: 0.6328 - val_loss: 5.8893 - val_acc: 0.5625
# Epoch 18/150
# 4/4 [==============================] - 1s 316ms/step - loss: 5.9226 - acc: 0.5625 - val_loss: 6.1549 - val_acc: 0.3125
# Epoch 19/150
# 4/4 [==============================] - 1s 329ms/step - loss: 5.7362 - acc: 0.6406 - val_loss: 5.5553 - val_acc: 0.6875
# Epoch 20/150
# 4/4 [==============================] - 1s 318ms/step - loss: 5.5260 - acc: 0.6875 - val_loss: 5.5143 - val_acc: 0.5000
# Epoch 21/150
# 4/4 [==============================] - 1s 337ms/step - loss: 5.4687 - acc: 0.6250 - val_loss: 5.4346 - val_acc: 0.6250
# Epoch 22/150
# 4/4 [==============================] - 1s 304ms/step - loss: 5.4179 - acc: 0.5781 - val_loss: 5.5561 - val_acc: 0.2500
# Epoch 23/150
# 4/4 [==============================] - 1s 318ms/step - loss: 5.2706 - acc: 0.7109 - val_loss: 5.0538 - val_acc: 0.6250
# Epoch 24/150
# 4/4 [==============================] - 1s 304ms/step - loss: 4.9555 - acc: 0.7031 - val_loss: 4.9182 - val_acc: 0.5625
# Epoch 25/150
# 4/4 [==============================] - 1s 316ms/step - loss: 4.9738 - acc: 0.6172 - val_loss: 4.8259 - val_acc: 0.5625
# Epoch 26/150
# 4/4 [==============================] - 1s 336ms/step - loss: 4.7382 - acc: 0.7188 - val_loss: 4.4328 - val_acc: 0.8750
# Epoch 27/150
# 4/4 [==============================] - 1s 319ms/step - loss: 4.6284 - acc: 0.6875 - val_loss: 4.6306 - val_acc: 0.5000
# Epoch 28/150
# 4/4 [==============================] - 1s 309ms/step - loss: 4.4909 - acc: 0.6562 - val_loss: 4.4949 - val_acc: 0.6250
# Epoch 29/150
# 4/4 [==============================] - 1s 310ms/step - loss: 4.3933 - acc: 0.6641 - val_loss: 4.3279 - val_acc: 0.6250
# Epoch 30/150
# 4/4 [==============================] - 1s 305ms/step - loss: 4.3379 - acc: 0.6797 - val_loss: 4.2080 - val_acc: 0.5625
# Epoch 31/150
# 4/4 [==============================] - 1s 319ms/step - loss: 4.0933 - acc: 0.7188 - val_loss: 4.1041 - val_acc: 0.6250
# Epoch 32/150
# 4/4 [==============================] - 1s 319ms/step - loss: 4.0003 - acc: 0.7891 - val_loss: 4.2121 - val_acc: 0.4375
# Epoch 33/150
# 4/4 [==============================] - 1s 291ms/step - loss: 3.9702 - acc: 0.6875 - val_loss: 4.1141 - val_acc: 0.5625
# Epoch 34/150
# 4/4 [==============================] - 1s 375ms/step - loss: 3.8903 - acc: 0.7109 - val_loss: 4.1483 - val_acc: 0.5000
# Epoch 35/150
# 4/4 [==============================] - 1s 347ms/step - loss: 3.7249 - acc: 0.7266 - val_loss: 3.6085 - val_acc: 0.7500
# Epoch 36/150
# 4/4 [==============================] - 1s 368ms/step - loss: 3.6675 - acc: 0.7031 - val_loss: 3.8151 - val_acc: 0.5625
# Epoch 37/150
# 4/4 [==============================] - 1s 370ms/step - loss: 3.6553 - acc: 0.6719 - val_loss: 3.2731 - val_acc: 0.8750
# Epoch 38/150
# 4/4 [==============================] - 1s 295ms/step - loss: 3.5616 - acc: 0.6406 - val_loss: 3.2329 - val_acc: 0.8125
# Epoch 39/150
# 4/4 [==============================] - 1s 341ms/step - loss: 3.4411 - acc: 0.6797 - val_loss: 3.6139 - val_acc: 0.4375
# Epoch 40/150
# 4/4 [==============================] - 1s 314ms/step - loss: 3.2508 - acc: 0.7344 - val_loss: 3.2924 - val_acc: 0.6875
# Epoch 41/150
# 4/4 [==============================] - 1s 336ms/step - loss: 3.2112 - acc: 0.7031 - val_loss: 3.3821 - val_acc: 0.6250
# Epoch 42/150
# 4/4 [==============================] - 1s 324ms/step - loss: 3.1300 - acc: 0.7109 - val_loss: 3.5668 - val_acc: 0.5625
# Epoch 43/150
# 4/4 [==============================] - 1s 323ms/step - loss: 3.1983 - acc: 0.6719 - val_loss: 3.1980 - val_acc: 0.4375
# Epoch 44/150
# 4/4 [==============================] - 1s 315ms/step - loss: 3.0469 - acc: 0.7031 - val_loss: 3.0407 - val_acc: 0.7500
# Epoch 45/150
# 4/4 [==============================] - 1s 297ms/step - loss: 2.9351 - acc: 0.7188 - val_loss: 3.0122 - val_acc: 0.7500
# Epoch 46/150
# 4/4 [==============================] - 1s 330ms/step - loss: 2.8271 - acc: 0.7266 - val_loss: 2.7016 - val_acc: 0.8125
# Epoch 47/150
# 4/4 [==============================] - 1s 315ms/step - loss: 2.7547 - acc: 0.7266 - val_loss: 2.6362 - val_acc: 0.8125
# Epoch 48/150
# 4/4 [==============================] - 1s 314ms/step - loss: 2.7454 - acc: 0.7344 - val_loss: 2.9153 - val_acc: 0.5000
# Epoch 49/150
# 4/4 [==============================] - 1s 320ms/step - loss: 2.7602 - acc: 0.6797 - val_loss: 2.4880 - val_acc: 0.7500
# Epoch 50/150
# 4/4 [==============================] - 1s 320ms/step - loss: 2.6596 - acc: 0.6719 - val_loss: 2.8424 - val_acc: 0.6250
# Epoch 51/150
# 4/4 [==============================] - 1s 338ms/step - loss: 2.4598 - acc: 0.8203 - val_loss: 2.5754 - val_acc: 0.7500
# Epoch 52/150
# 4/4 [==============================] - 1s 319ms/step - loss: 2.3994 - acc: 0.7969 - val_loss: 2.3803 - val_acc: 0.8125
# Epoch 53/150
# 4/4 [==============================] - 1s 324ms/step - loss: 2.4956 - acc: 0.7422 - val_loss: 2.6057 - val_acc: 0.5625
# Epoch 54/150
# 4/4 [==============================] - 1s 316ms/step - loss: 2.3528 - acc: 0.8047 - val_loss: 2.5070 - val_acc: 0.7500
# Epoch 55/150
# 4/4 [==============================] - 1s 333ms/step - loss: 2.3562 - acc: 0.7344 - val_loss: 2.5859 - val_acc: 0.6875
# Epoch 56/150
# 4/4 [==============================] - 1s 320ms/step - loss: 2.3583 - acc: 0.7578 - val_loss: 2.7074 - val_acc: 0.6250
# Epoch 57/150
# 4/4 [==============================] - 1s 341ms/step - loss: 2.3109 - acc: 0.7422 - val_loss: 2.1889 - val_acc: 0.8750
# Epoch 58/150
# 4/4 [==============================] - 1s 311ms/step - loss: 2.2250 - acc: 0.6875 - val_loss: 1.9588 - val_acc: 0.9375
# Epoch 59/150
# 4/4 [==============================] - 1s 330ms/step - loss: 2.1697 - acc: 0.7422 - val_loss: 2.1302 - val_acc: 0.8125
# Epoch 60/150
# 4/4 [==============================] - 1s 312ms/step - loss: 1.9820 - acc: 0.8438 - val_loss: 1.8623 - val_acc: 0.8750
# Epoch 61/150
# 4/4 [==============================] - 1s 322ms/step - loss: 2.1244 - acc: 0.7422 - val_loss: 2.0636 - val_acc: 0.8125
# Epoch 62/150
# 4/4 [==============================] - 1s 305ms/step - loss: 1.8888 - acc: 0.8047 - val_loss: 2.0100 - val_acc: 0.6875
# Epoch 63/150
# 4/4 [==============================] - 1s 329ms/step - loss: 2.0809 - acc: 0.7031 - val_loss: 2.2797 - val_acc: 0.6250
# Epoch 64/150
# 4/4 [==============================] - 1s 312ms/step - loss: 2.0675 - acc: 0.7344 - val_loss: 2.0718 - val_acc: 0.5625
# Epoch 65/150
# 4/4 [==============================] - 1s 309ms/step - loss: 1.8543 - acc: 0.7812 - val_loss: 1.8875 - val_acc: 0.7500
# Epoch 66/150
# 4/4 [==============================] - 1s 321ms/step - loss: 1.8453 - acc: 0.7812 - val_loss: 1.9285 - val_acc: 0.6875
# Epoch 67/150
# 4/4 [==============================] - 1s 339ms/step - loss: 1.8949 - acc: 0.7578 - val_loss: 1.9330 - val_acc: 0.6875
# Epoch 68/150
# 4/4 [==============================] - 1s 319ms/step - loss: 1.8151 - acc: 0.7656 - val_loss: 1.7904 - val_acc: 0.7500
# Epoch 69/150
# 4/4 [==============================] - 1s 314ms/step - loss: 1.8593 - acc: 0.6797 - val_loss: 1.8257 - val_acc: 0.6875
# Epoch 70/150
# 4/4 [==============================] - 1s 326ms/step - loss: 1.6307 - acc: 0.8203 - val_loss: 1.8208 - val_acc: 0.6875
# Epoch 71/150
# 4/4 [==============================] - 1s 303ms/step - loss: 1.7052 - acc: 0.7656 - val_loss: 1.5978 - val_acc: 0.8750
# Epoch 72/150
# 4/4 [==============================] - 1s 314ms/step - loss: 1.6264 - acc: 0.7891 - val_loss: 1.7907 - val_acc: 0.7500
# Epoch 73/150
# 4/4 [==============================] - 1s 312ms/step - loss: 1.6601 - acc: 0.7812 - val_loss: 1.6221 - val_acc: 0.7500
# Epoch 74/150
# 4/4 [==============================] - 1s 305ms/step - loss: 1.5883 - acc: 0.7656 - val_loss: 1.3513 - val_acc: 1.0000
# Epoch 75/150
# 4/4 [==============================] - 1s 310ms/step - loss: 1.5691 - acc: 0.7812 - val_loss: 1.5863 - val_acc: 0.7500
# Epoch 76/150
# 4/4 [==============================] - 1s 329ms/step - loss: 1.5495 - acc: 0.7891 - val_loss: 1.7032 - val_acc: 0.6250
# Epoch 77/150
# 4/4 [==============================] - 1s 325ms/step - loss: 1.5861 - acc: 0.7500 - val_loss: 1.4591 - val_acc: 0.8125
# Epoch 78/150
# 4/4 [==============================] - 1s 326ms/step - loss: 1.5074 - acc: 0.7734 - val_loss: 1.5528 - val_acc: 0.8750
# Epoch 79/150
# 4/4 [==============================] - 1s 329ms/step - loss: 1.5124 - acc: 0.7578 - val_loss: 1.2839 - val_acc: 0.8750
# Epoch 80/150
# 4/4 [==============================] - 1s 305ms/step - loss: 1.4808 - acc: 0.7734 - val_loss: 1.3370 - val_acc: 0.8125
# Epoch 81/150
# 4/4 [==============================] - 1s 308ms/step - loss: 1.4490 - acc: 0.8047 - val_loss: 1.4433 - val_acc: 0.8125
# Epoch 82/150
# 4/4 [==============================] - 1s 327ms/step - loss: 1.4807 - acc: 0.7656 - val_loss: 1.7034 - val_acc: 0.6250
# Epoch 83/150
# 4/4 [==============================] - 1s 346ms/step - loss: 1.2848 - acc: 0.8438 - val_loss: 1.1881 - val_acc: 0.9375
# Epoch 84/150
# 4/4 [==============================] - 1s 329ms/step - loss: 1.3117 - acc: 0.8125 - val_loss: 1.3436 - val_acc: 0.7500
# Epoch 85/150
# 4/4 [==============================] - 1s 315ms/step - loss: 1.3068 - acc: 0.8281 - val_loss: 1.5469 - val_acc: 0.6250
# Epoch 86/150
# 4/4 [==============================] - 1s 314ms/step - loss: 1.5094 - acc: 0.7188 - val_loss: 1.2793 - val_acc: 0.8750
# Epoch 87/150
# 4/4 [==============================] - 1s 306ms/step - loss: 1.2424 - acc: 0.8438 - val_loss: 1.1101 - val_acc: 0.8750
# Epoch 88/150
# 4/4 [==============================] - 1s 320ms/step - loss: 1.3228 - acc: 0.7578 - val_loss: 1.3922 - val_acc: 0.7500
# Epoch 89/150
# 4/4 [==============================] - 1s 321ms/step - loss: 1.3090 - acc: 0.7734 - val_loss: 1.4848 - val_acc: 0.6250
# Epoch 90/150
# 4/4 [==============================] - 1s 309ms/step - loss: 1.1987 - acc: 0.8438 - val_loss: 1.4701 - val_acc: 0.6250
# Epoch 91/150
# 4/4 [==============================] - 1s 316ms/step - loss: 1.2914 - acc: 0.7734 - val_loss: 1.6640 - val_acc: 0.6250
# Epoch 92/150
# 4/4 [==============================] - 1s 318ms/step - loss: 1.2764 - acc: 0.7734 - val_loss: 1.2778 - val_acc: 0.8125
# Epoch 93/150
# 4/4 [==============================] - 1s 331ms/step - loss: 1.2284 - acc: 0.8125 - val_loss: 1.0747 - val_acc: 0.9375
# Epoch 94/150
# 4/4 [==============================] - 1s 316ms/step - loss: 1.1806 - acc: 0.7891 - val_loss: 0.9805 - val_acc: 1.0000
# Epoch 95/150
# 4/4 [==============================] - 1s 314ms/step - loss: 1.1758 - acc: 0.7969 - val_loss: 1.2566 - val_acc: 0.6875
# Epoch 96/150
# 4/4 [==============================] - 1s 317ms/step - loss: 1.1568 - acc: 0.7578 - val_loss: 1.2407 - val_acc: 0.6250
# Epoch 97/150
# 4/4 [==============================] - 1s 313ms/step - loss: 1.0632 - acc: 0.8281 - val_loss: 1.2900 - val_acc: 0.7500
# Epoch 98/150
# 4/4 [==============================] - 2s 404ms/step - loss: 1.1342 - acc: 0.7891 - val_loss: 1.3644 - val_acc: 0.6250
# Epoch 99/150
# 4/4 [==============================] - 1s 373ms/step - loss: 1.0041 - acc: 0.8516 - val_loss: 1.1474 - val_acc: 0.7500
# Epoch 100/150
# 4/4 [==============================] - 1s 336ms/step - loss: 1.0464 - acc: 0.8281 - val_loss: 1.1443 - val_acc: 0.8750
# Epoch 101/150
# 4/4 [==============================] - 1s 313ms/step - loss: 1.0302 - acc: 0.8281 - val_loss: 1.1320 - val_acc: 0.7500
# Epoch 102/150
# 4/4 [==============================] - 1s 298ms/step - loss: 1.0301 - acc: 0.7812 - val_loss: 1.0969 - val_acc: 0.8125
# Epoch 103/150
# 4/4 [==============================] - 1s 299ms/step - loss: 1.0319 - acc: 0.8281 - val_loss: 1.1731 - val_acc: 0.8125
# Epoch 104/150
# 4/4 [==============================] - 1s 317ms/step - loss: 0.9735 - acc: 0.8594 - val_loss: 1.0930 - val_acc: 0.8125
# Epoch 105/150
# 4/4 [==============================] - 1s 331ms/step - loss: 1.0957 - acc: 0.7656 - val_loss: 1.0211 - val_acc: 0.8750
# Epoch 106/150
# 4/4 [==============================] - 1s 311ms/step - loss: 1.0568 - acc: 0.8047 - val_loss: 1.1566 - val_acc: 0.6875
# Epoch 107/150
# 4/4 [==============================] - 1s 329ms/step - loss: 0.8682 - acc: 0.8984 - val_loss: 1.0321 - val_acc: 0.8125
# Epoch 108/150
# 4/4 [==============================] - 1s 327ms/step - loss: 0.9384 - acc: 0.8359 - val_loss: 1.2728 - val_acc: 0.7500
# Epoch 109/150
# 4/4 [==============================] - 1s 311ms/step - loss: 1.0450 - acc: 0.8281 - val_loss: 1.0549 - val_acc: 0.8125
# Epoch 110/150
# 4/4 [==============================] - 1s 327ms/step - loss: 1.0189 - acc: 0.8047 - val_loss: 0.9090 - val_acc: 0.8750
# Epoch 111/150
# 4/4 [==============================] - 1s 326ms/step - loss: 0.9519 - acc: 0.8359 - val_loss: 1.2743 - val_acc: 0.5625
# Epoch 112/150
# 4/4 [==============================] - 1s 315ms/step - loss: 0.9030 - acc: 0.8438 - val_loss: 1.0143 - val_acc: 0.8750
# Epoch 113/150
# 4/4 [==============================] - 1s 334ms/step - loss: 1.0459 - acc: 0.7969 - val_loss: 0.8191 - val_acc: 0.8125
# Epoch 114/150
# 4/4 [==============================] - 1s 314ms/step - loss: 0.9910 - acc: 0.8047 - val_loss: 1.0974 - val_acc: 0.7500
# Epoch 115/150
# 4/4 [==============================] - 1s 310ms/step - loss: 0.9353 - acc: 0.8672 - val_loss: 0.9579 - val_acc: 0.8125
# Epoch 116/150
# 4/4 [==============================] - 1s 353ms/step - loss: 0.9790 - acc: 0.7578 - val_loss: 0.8933 - val_acc: 0.8750
# Epoch 117/150
# 4/4 [==============================] - 1s 305ms/step - loss: 0.8774 - acc: 0.8281 - val_loss: 0.8794 - val_acc: 0.7500
# Epoch 118/150
# 4/4 [==============================] - 1s 307ms/step - loss: 0.9155 - acc: 0.8594 - val_loss: 1.1311 - val_acc: 0.7500
# Epoch 119/150
# 4/4 [==============================] - 1s 321ms/step - loss: 0.9551 - acc: 0.8281 - val_loss: 1.3642 - val_acc: 0.5625
# Epoch 120/150
# 4/4 [==============================] - 1s 323ms/step - loss: 0.9845 - acc: 0.7422 - val_loss: 0.7782 - val_acc: 0.9375
# Epoch 121/150
# 4/4 [==============================] - 1s 321ms/step - loss: 0.8776 - acc: 0.8516 - val_loss: 1.0537 - val_acc: 0.7500
# Epoch 122/150
# 4/4 [==============================] - 1s 344ms/step - loss: 1.0513 - acc: 0.7344 - val_loss: 0.9728 - val_acc: 0.6875
# Epoch 123/150
# 4/4 [==============================] - 1s 327ms/step - loss: 0.8325 - acc: 0.8672 - val_loss: 0.9747 - val_acc: 0.6875
# Epoch 124/150
# 4/4 [==============================] - 1s 293ms/step - loss: 0.8752 - acc: 0.8281 - val_loss: 0.7524 - val_acc: 0.8125
# Epoch 125/150
# 4/4 [==============================] - 1s 344ms/step - loss: 0.7805 - acc: 0.8594 - val_loss: 0.9383 - val_acc: 0.7500
# Epoch 126/150
# 4/4 [==============================] - 1s 315ms/step - loss: 0.9648 - acc: 0.8047 - val_loss: 0.6859 - val_acc: 0.9375
# Epoch 127/150
# 4/4 [==============================] - 1s 199ms/step - loss: 0.8109 - acc: 0.8281 - val_loss: 0.8165 - val_acc: 0.8750
# Epoch 128/150
# 4/4 [==============================] - 1s 218ms/step - loss: 0.8612 - acc: 0.8438 - val_loss: 1.0250 - val_acc: 0.6875
# Epoch 129/150
# 4/4 [==============================] - 1s 220ms/step - loss: 0.8504 - acc: 0.7969 - val_loss: 0.6254 - val_acc: 0.8750
# Epoch 130/150
# 4/4 [==============================] - 1s 206ms/step - loss: 0.9491 - acc: 0.7812 - val_loss: 0.8840 - val_acc: 0.8125
# Epoch 131/150
# 4/4 [==============================] - 1s 207ms/step - loss: 0.8036 - acc: 0.8438 - val_loss: 1.0266 - val_acc: 0.6875
# Epoch 132/150
# 4/4 [==============================] - 1s 194ms/step - loss: 0.7997 - acc: 0.8828 - val_loss: 1.1313 - val_acc: 0.6875
# Epoch 133/150
# 4/4 [==============================] - 1s 188ms/step - loss: 0.8094 - acc: 0.8047 - val_loss: 1.0568 - val_acc: 0.6875
# Epoch 134/150
# 4/4 [==============================] - 1s 185ms/step - loss: 0.7448 - acc: 0.8594 - val_loss: 0.8063 - val_acc: 0.8750
# Epoch 135/150
# 4/4 [==============================] - 1s 187ms/step - loss: 0.7334 - acc: 0.8672 - val_loss: 0.8860 - val_acc: 0.6875
# Epoch 136/150
# 4/4 [==============================] - 1s 193ms/step - loss: 0.8525 - acc: 0.8281 - val_loss: 0.8493 - val_acc: 0.8750
# Epoch 137/150
# 4/4 [==============================] - 1s 187ms/step - loss: 0.7772 - acc: 0.8125 - val_loss: 0.7516 - val_acc: 0.8750
# Epoch 138/150
# 4/4 [==============================] - 1s 190ms/step - loss: 0.6885 - acc: 0.8594 - val_loss: 0.8642 - val_acc: 0.8125
# Epoch 139/150
# 4/4 [==============================] - 1s 186ms/step - loss: 0.7577 - acc: 0.8594 - val_loss: 0.9258 - val_acc: 0.8125
# Epoch 140/150
# 4/4 [==============================] - 1s 193ms/step - loss: 0.7630 - acc: 0.8203 - val_loss: 1.2747 - val_acc: 0.5000
# Epoch 141/150
# 4/4 [==============================] - 1s 186ms/step - loss: 0.6361 - acc: 0.8750 - val_loss: 1.0758 - val_acc: 0.6875
# Epoch 142/150
# 4/4 [==============================] - 1s 190ms/step - loss: 0.7862 - acc: 0.8203 - val_loss: 0.9826 - val_acc: 0.7500
# Epoch 143/150
# 4/4 [==============================] - 1s 185ms/step - loss: 0.7624 - acc: 0.8125 - val_loss: 1.1016 - val_acc: 0.8125
# Epoch 144/150
# 4/4 [==============================] - 1s 190ms/step - loss: 0.8221 - acc: 0.8125 - val_loss: 0.9708 - val_acc: 0.6875
# Epoch 145/150
# 4/4 [==============================] - 1s 189ms/step - loss: 0.8506 - acc: 0.7812 - val_loss: 1.0618 - val_acc: 0.6875
# Epoch 146/150
# 4/4 [==============================] - 1s 193ms/step - loss: 0.6903 - acc: 0.8203 - val_loss: 0.8894 - val_acc: 0.7500
# Epoch 147/150
# 4/4 [==============================] - 1s 191ms/step - loss: 0.6917 - acc: 0.8359 - val_loss: 0.7166 - val_acc: 0.8125
# Epoch 148/150
# 4/4 [==============================] - 1s 187ms/step - loss: 0.7302 - acc: 0.8672 - val_loss: 1.0543 - val_acc: 0.7500
# Epoch 149/150
# 4/4 [==============================] - 1s 183ms/step - loss: 0.9367 - acc: 0.7656 - val_loss: 0.8979 - val_acc: 0.7500
# Epoch 150/150
# 4/4 [==============================] - 1s 187ms/step - loss: 0.8110 - acc: 0.8125 - val_loss: 1.5703 - val_acc: 0.5000

# %%
import numpy as np
from keras.models import load_model

model = load_model('model_cnn_dyslexia.h5')

from keras.applications.vgg16 import preprocess_input
from keras.preprocessing.image import ImageDataGenerator

data_generator = ImageDataGenerator(preprocessing_function=preprocess_input)

test_generator = data_generator.flow_from_directory(
    directory='test',
    target_size=(29, 29),
    batch_size=1,
    class_mode=None,  # This should be None since you're not using labels
    shuffle=False,
    seed=123
)

pred = model.predict_generator(test_generator, steps=len(test_generator), verbose=1)
print(pred)
predicted_class_indices = np.argmax(pred, axis=1)
print(predicted_class_indices)
label = ['corrected', 'normal','reversal']
print(label[predicted_class_indices[0]])
# Out:
# Found 2 images belonging to 1 classes.
# 2/2 [==============================] - 0s 162ms/step
# [[0.1396447  0.59621435 0.2641409 ]
#  [0.03816742 0.7360771  0.22575556]]
# [1 1]
# normal
